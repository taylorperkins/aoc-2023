# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.algorithms.components import connected_components

# %matplotlib inline

# %%
with open("./input.txt") as f:
    data = f.read()

# %%
G = nx.Graph()

# %%
nodes = set()
edges = set()

for line in data.splitlines():
    parent, children = line.split(": ")
    children = children.split(" ")
    
    nodes.add(parent)
    for child in children:
        nodes.add(child)
        edges.add((parent, child))

# %%
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# %%
f, ax = plt.subplots(figsize=(20, 20))
nx.draw(G, with_labels=True, font_weight='bold', ax=ax)

plt.show()

# %%
[e for e in edges if "zkv" in e]
# Out:
# [('tkq', 'zkv'), ('zkv', 'hkp'), ('zkv', 'kzl'), ('zxb', 'zkv')]

# %%
("scf", "lkf"), ("pgl", "mtl"),

# %%
G.remove_edges_from([("pzl", "hfx"), ("nvd", "jqt"), ("cmg", "bvb")])

# %%
subax1 = plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')

plt.show()

# %%
# G is the networkx graph 
Ga, Gb = [G.subgraph(c) for c in connected_components(G)]
len(Ga.nodes) * len(Gb.nodes)
# Out:
# 54
